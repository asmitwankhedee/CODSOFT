# %% [markdown]
# <a href="https://colab.research.google.com/github/asmitwankhedee/CODSOFT/blob/main/Credit_Card_Fraud_task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Required Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Import Dataset from Kaggle through API

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mlg-ulb/creditcardfraud")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'creditcardfraud' dataset.
# Path to dataset files: /kaggle/input/creditcardfraud

# %%
import os

# %% [markdown]
# Getting Path of Dataset

# %%
os.listdir(path)
# Out:
# ['creditcard.csv']

# %% [markdown]
# Reading Dataset

# %%
df=pd.read_csv(path+'/creditcard.csv')

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %% [markdown]
# Finding Shape

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# Finding Size

# %%
df.size
# Out:
# 8829017

# %% [markdown]
# Finding all Datatypes of columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# Finding Top Row

# %%
df.head(1)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
#
# [1 rows x 31 columns]

# %% [markdown]
# Finding Bottom Row

# %%
df.tail(1)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 284806  172792.0 -0.533413 -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7       V8       V9  ...       V21       V22       V23  \
# 284806  1.577006 -0.41465  0.48618  ...  0.261057  0.643078  0.376777
#
#              V24       V25       V26       V27       V28  Amount  Class
# 284806  0.008797 -0.473649 -0.818267 -0.002415  0.013649   217.0      0
#
# [1 rows x 31 columns]

# %% [markdown]
# Finding Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(1081)

# %% [markdown]
# Removing Duplicates

# %%
df=df.drop_duplicates().copy()

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# Finding Distribution of Dataset

# %%
df.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %% [markdown]
# Finding Unique values in Class

# %%
df['Class'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# Finding Unique values in Amount

# %%
list(df['Amount'].unique())
# Out:
# [np.float64(149.62),
#  np.float64(2.69),
#  np.float64(378.66),
#  np.float64(123.5),
#  np.float64(69.99),
#  np.float64(3.67),
#  np.float64(4.99),
#  np.float64(40.8),
#  np.float64(93.2),
#  np.float64(3.68),
#  np.float64(7.8),
#  np.float64(9.99),
#  np.float64(121.5),
#  np.float64(27.5),
#  np.float64(58.8),
#  np.float64(15.99),
#  np.float64(12.99),
#  np.float64(0.89),
#  np.float64(46.8),
#  np.float64(5.0),
#  np.float64(231.71),
#  np.float64(34.09),
#  np.float64(2.28),
#  np.float64(22.75),
#  np.float64(26.43),
#  np.float64(41.88),
#  np.float64(16.0),
#  np.float64(33.0),
#  np.float64(17.28),
#  np.float64(4.45),
#  np.float64(6.14),
#  np.float64(1.77),
#  np.float64(30.49),
#  np.float64(1.8),
#  np.float64(20.53),
#  np.float64(6.54),
#  np.float64(29.89),
#  np.float64(2.35),
#  np.float64(14.8),
#  np.float64(9.1),
#  np.float64(21.34),
#  np.float64(18.95),
#  np.float64(30.9),
#  np.float64(20.22),
#  np.float64(0.99),
#  np.float64(1402.95),
# ...

# %%
df['Amount'].describe()
# Out:
# count    283726.000000
# mean         88.472687
# std         250.399437
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.510000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# Finding Outliers In Amount through Boxplot

# %%
sns.boxplot(df['Amount'])
# Out:
# <Axes: ylabel='Amount'>

# %% [markdown]
# Finding Distribution of Amount column

# %%
sns.distplot(df['Amount'])
# Out:
# /tmp/ipykernel_5038/2945972173.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Amount'])
# <Axes: xlabel='Amount', ylabel='Density'>

# %%
Q1=df['Amount'].quantile(0.25)
Q2=df['Amount'].quantile(0.50)
Q3=df['Amount'].quantile(0.75)
print(Q1)
print(Q2)
print(Q3)
# Out:
# 5.6
# 22.0
# 77.51

# %% [markdown]
# Finding Inter Quantile Range of Amount Column

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 71.91000000000001

# %% [markdown]
# Finding Upper and Lower Limit

# %%
upper_limit=Q3+1.5*IQR
lower_limit=Q1-1.5*IQR
print(upper_limit)
print(lower_limit)
# Out:
# 185.375
# -102.26500000000001

# %% [markdown]
# Finding Skewness of data through Bowley Method

# %%
Bowley=(Q3+Q1-2*Q2)/(Q3-Q1)
print(Bowley)
# Out:
# 0.5438742873035738

# %% [markdown]
# Transform The data through Log Transformation

# %%
df['Amount']=np.log1p(df['Amount'])

# %% [markdown]
# Distribution After Transformation

# %%
sns.distplot(df['Amount'])
# Out:
# /tmp/ipykernel_5038/2945972173.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Amount'])
# <Axes: xlabel='Amount', ylabel='Density'>

# %% [markdown]
# BoxPlot

# %%
sns.boxplot(df['Amount'])
# Out:
# <Axes: ylabel='Amount'>

# %% [markdown]
# Finding Unique values in Time

# %%
df['Time'].unique()
# Out:
# array([0.00000e+00, 1.00000e+00, 2.00000e+00, ..., 1.72787e+05,
#        1.72788e+05, 1.72792e+05])

# %% [markdown]
# Checking Outliers in Time through Boxplot

# %%
sns.boxplot(df['Time'])
# Out:
# <Axes: ylabel='Time'>

# %% [markdown]
# Cheking Distribution of Time column through Distribution Plot

# %%
sns.distplot(df['Time'])
# Out:
# /tmp/ipykernel_5038/1125727111.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Time'])
# <Axes: xlabel='Time', ylabel='Density'>

# %% [markdown]
# Cheking Distribution of Class column through Distribution Plot

# %%
sns.distplot(df['Class'])
# Out:
# /tmp/ipykernel_5038/693553272.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Class'])
# <Axes: xlabel='Class', ylabel='Density'>

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Amount'], bins=50)

plt.title('Transaction Amount Distribution')
plt.xlabel('Amount')
plt.ylabel('Frequency')

plt.show()

# %%
counts = df['Class'].value_counts()

plt.figure(figsize=(6,4))
plt.bar(counts.index, counts.values)

plt.title('Fraud vs Non-Fraud Transactions')
plt.xlabel('Class (0 = Normal, 1 = Fraud)')
plt.ylabel('Count')

plt.xticks([0,1])

plt.show()

# %%
sns.pairplot(df)
# Out:
# <module 'seaborn' from '/usr/local/lib/python3.12/dist-packages/seaborn/__init__.py'>

# %%
X=df.drop(columns=['Class'],axis=1)
y=df['Class']

# %% [markdown]
# Import Libraries

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# Divide Data in 80% train and 20% test

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %% [markdown]
# Using RandomForest Model

# %%
model=RandomForestClassifier()

# %% [markdown]
# Train the Model

# %%
model.fit(X_train,y_train)

# %%
y_pred=model.predict(X_test)

# %% [markdown]
# Confusion Matrix

# %%
print(confusion_matrix(y_test,y_pred))

# %% [markdown]
# Classification Report

# %%
print(classification_report(y_test,y_pred))

# %% [markdown]
# Accuracy of model is 100% Having no Dataleakage and Overfitting Errors
